# %% [markdown]
# 1-What is a parameter?
#
#  -  A parameter in machine learning is a configuration variable internal to the model whose value can be estimated from data.
#
#
# 2-What is correlation? What does negative correlation mean?
#
#  -  Correlation is a statistical measure that expresses the extent to which two variables are linearly related.Negative correlation means that there is a relationship between two variables where one variable increases as the other decreases.
#
#
# 3-Define Machine Learning. What are the main components in Machine Learning?
#
#  -  Machine learning is a field of computer science that uses statistical techniques to give computer systems the ability to "learn" from data, without being explicitly programmed.The main components in Machine Learning are data, models, algorithms, and evaluation.
#
#
# 4-How does loss value help in determining whether the model is good or not?
#
#  -  The loss value helps determine whether a model is good or not by quantifying the error between the model's predictions and the actual values. A lower loss value indicates that the model's predictions are closer to the true values, suggesting a better model.
#
#
# 5-What are continuous and categorical variables?
#
#  -  Continuous variables are numerical variables that can take on any value within a range, while categorical variables represent categories or groups.
#
#
# 6-How do we handle categorical variables in Machine Learning? What are the common techniques?
#
#  -  In machine learning, categorical variables are handled using techniques like one-hot encoding, label encoding, and target encoding.
#
#
# 7-What do you mean by training and testing a dataset?
#
#  -  raining a dataset involves using a portion of the data to teach a machine learning model, while testing a dataset involves using a separate portion to evaluate the model's performance.
#
#
# 8-What is sklearn.preprocessing?
#
#  -  'sklearn.preprocessing' is a module in the scikit-learn library that provides various utility functions and transformer classes to preprocess data before feeding it to a machine learning model. It includes tools for scaling, normalization, encoding categorical features, and more.
#
#
# 9-What is a Test set?
#
#  -  A test set is a dataset used to evaluate the performance of a machine learning model after it has been trained. It helps assess how well the model generalizes to new, unseen data.
#
#
# 10-How do we split data for model fitting (training and testing) in Python?
# How do you approach a Machine Learning problem ?
#
#  -  In Python, you can split data for model fitting using the `train_test_split` function from the `scikit-learn` library.
#
#  approach a machine learning problem:
#
# 1.  Define the problem: Clearly understand the goal and what you want to achieve.
# 2.  Data collection: Gather relevant data for your problem.
# 3.  Data preprocessing: Clean, transform, and prepare the data (handle missing values, scale features, encode categorical variables, etc.).
# 4.  Feature engineering: Create new features or modify existing ones to improve model performance.
# 5.  Model selection: Choose an appropriate machine learning model based on the problem type (classification, regression, etc.).
# 6.  Model training: Train the model using the training data.
# 7.  Model evaluation: Assess the model's performance using the testing data and appropriate metrics.
# 8.  Model tuning: Optimize the model's parameters to improve performance.
# 9.  Deployment: Deploy the model for real-world use.
# 10. Monitoring and maintenance: Continuously monitor the model's performance and retrain it as needed.
#
#
# 11-Why do we have to perform EDA before fitting a model to the data?
#
#  -  Performing EDA (Exploratory Data Analysis) before fitting a model is crucial because it helps you understand the data, identify patterns, detect anomalies, and gain insights that inform feature engineering, model selection, and preprocessing steps, ultimately leading to better model performance.
#
#
# 12-What is correlation?
#
#  -  Correlation measures the strength and direction of the linear relationship between two variables. It ranges from -1 to +1, where -1 indicates a perfect negative correlation, +1 indicates a perfect positive correlation, and 0 indicates no correlation.
#
#
# 13-What does negative correlation mean?
#
#  -  Negative correlation means that as one variable increases, the other variable tends to decrease.
#
#
# 14-How can you find correlation between variables in Python?
#
#  -   We can find the correlation between variables using the '.corr()' method in pandas. This method calculates the correlation matrix for a DataFrame
#
#
# 15-What is causation? Explain difference between correlation and causation with an example.
#
#  -  Causation means that one event directly influences another, where the first event causes the second event to occur.The key difference between correlation and causation is that correlation measures the relationship between two variables, while causation implies that one variable causes a change in another. Correlation does not imply causation.
#
#
# 16-What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
#  -  some common types of optimizers:
#
# 1.  Gradient Descent:
#     *   Explanation: The most basic optimizer. It calculates the gradient (slope) of the loss function with respect to the model's parameters and updates the parameters in the opposite direction of the gradient to minimize the loss.
#     *   Example: Imagine you're in a valley (the loss function) and want to reach the lowest point. Gradient descent is like taking small steps downhill in the direction of the steepest slope.
# 2.  Stochastic Gradient Descent (SGD):
#     *   Explanation: A variant of gradient descent that uses a single data point (or a small batch) to estimate the gradient in each iteration. This makes it faster than standard gradient descent, especially for large datasets.
#     *   Example: Instead of calculating the average slope for the entire valley, SGD estimates the slope based on where you are standing. It's noisier but faster.
# 3.  Momentum:
#     *   Explanation: Improves SGD by adding momentum. It helps the optimizer to accelerate in the relevant direction and dampen oscillations. It's like a ball rolling down a hill – it gains momentum and smooths out the path.
#     *   Example: The ball rolling down the hill, picking up speed and overcoming small bumps along the way.
# 4.  Adam (Adaptive Moment Estimation):
#     *   Explanation: Combines the concepts of momentum and adaptive learning rates. It uses estimates of the first and second moments of the gradients to adapt the learning rates for each parameter.
#     *   Example: Adam is like a smart hiker who adjusts their pace (learning rate) based on the terrain (gradients) and their past movements (momentum).
# 5.  RMSprop (Root Mean Square Propagation):
#     *   Explanation: An adaptive learning rate method that adjusts the learning rate for each parameter based on the average of the squared gradients.
#     *   Example: RMSprop is like adjusting the sensitivity of a measuring device based on the fluctuations of the signal.
#
# These optimizers are used to train machine learning models, with each having its strengths and weaknesses depending on the specific problem and dataset.
#
#
# 17-What is sklearn.linear_model ?
#
#  -  sklearn.linear_model is a module in the scikit-learn library that provides a collection of linear models for various machine learning tasks. These models are used for regression and classification problems where the relationship between the features and the target variable is assumed to be linear.
#
#
# 18-What does model.fit() do? What arguments must be given?
#
#  -  The `model.fit()` method is used to train a machine learning model on a given dataset. It essentially teaches the model how to make predictions based on the provided data.
#
#
# 19-What does model.predict() do? What arguments must be given?
#
#  -  The `model.predict()` method is used to generate predictions using a trained machine learning model. It takes new, unseen data as input and returns the model's predicted output for that data.
#
#
# 20-What are continuous and categorical variables?
#
#  -  Continuous variables measure quantities on a scale, while categorical variables classify data into distinct groups or categories. The type of variable influences the statistical methods and analyses that can be applied.
#
#
# 21-What is feature scaling? How does it help in Machine Learning?
#
#  -  Feature scaling is a technique used in machine learning to standardize the range of independent features or variables in your data. It's an important preprocessing step that helps to ensure that all features contribute equally to the analysis.
#
#
# 22-How do we perform scaling in Python?
#
#  -  We can perform feature scaling in Python using the 'scikit-learn' library, which provides several methods for scaling your data.
#
#
# 23-What is sklearn.preprocessing?
#
#  -  'sklearn.preprocessing' is a module in the scikit-learn library that provides various utility functions and transformer classes for preprocessing data before feeding it to machine learning models. These tools help you prepare your data by cleaning, transforming, and scaling it to improve model performance.
#
#
# 24-How do we split data for model fitting (training and testing) in Python?
#
#  -  You can split your data into training and testing sets in Python using the 'train_test_split' function from the 'scikit-learn' library.
#
#
# 25-Explain data encoding?
#
#  -  Data encoding is the process of converting data from one format to another, often to make it suitable for a specific purpose. In the context of machine learning, data encoding typically refers to converting categorical data (like text or labels) into numerical data that can be used by machine learning algorithms.
